# %% [markdown]
# # 4A: Explaining Variation in State Homelessness

# %%
# This code will load the R packages we will use
suppressPackageStartupMessages({
    library(coursekata)
})

# Load the States data
States <- read.csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vSGPPBJEKYHYu563seooxlUmhkUGVHQUeedgHsviPhYv5OtsOOOBnPKdFsIB1J0y6zmxXQ7I_CNnh64/pub?gid=2140707809&single=true&output=csv")

# %% [markdown]
# ## 1.0 - Which states might have higher homelessness rates?

# %% [markdown]
# Researchers and political leaders are interested in tackling the homelessness problem. In order to try to find solutions to this issue, it would be useful to know what causes it. Today, we're going to explore different explanations for why some states have more homelessness than others.
#
# First, let's learn a little bit about the data. We'll learn how homelessness is measured in states.

# %% [markdown]
# 1.1 - Take a look at a data frame called `States` using functions like `head()` and `glimpse()`.
#
# Full descriptions of the variables in the dataset can be found [here](https://docs.google.com/document/d/e/2PACX-1vTLsVPYffaAG_IoJPgGEAtw56b5nOTk7zbfm8v3Q5zjeq9vXy_-bWaExcqOurGcaPxxOzMxR5Vyt2L_/pub).

# %%
#write some code here to look at the data

# %% [markdown]
# 1.2 - Take a look at the variables called `ShelteredPITHomeless`, `UnshelteredPITHomeless`, and `PITHomeless` . Which variable(s) should we use to look at how homelessness varies across different states? Why?

# %% [markdown]
# 1.3 - To explore variation in homelessness rates, make a visualization of that variable. What do you notice? Is there anything surprising about this distribution?

# %%
#make a visualization here

# %% [markdown]
# ## 2.0 - Explaining Variation in `PITHomeless`

# %% [markdown]
# 2.1 - What characteristics of a state might help explain their homelessness rates? Take a look at some of the variables in the data frame for some ideas.

# %% [markdown]
# 2.2 - *Quick Review*: What does it mean to “explain variation”?

# %% [markdown]
# 2.3 - Let's work with 3 ideas (these are common hypotheses that students come up with about homelessness): Which of these variables do you think will likely explain more of the variation in a state's `PITHomeless`: `SubstanceAbuse`, `HouseholdIncomeK` or `MedianRent `? Why?
#
# Write your chosen hypothesis as a word equation.

# %% [markdown]
# 2.4 - Let's apply our informal definition of explain variation. What would it mean for each of these variables to "explain variation" in homelessness?

# %% [markdown]
# For the next section, **you will be assigned to work in groups on one of the 3 models**. Work on your assigned model first. If you have more time, try the other models.

# %% [markdown]
# ## 3.0 - Exploring `PITHomeless` = `SubstanceAbuse` + Other Stuff.

# %% [markdown]
# 3.1 - Let's use some code to look at the first 6 rows of this data set. This data has a lot of variables in it. Can we can combine head() and select() to look at the first 6 rows of only the variables `State`, `PITHomeless`, and `SubstanceAbuse`? Try it!

# %%
#try it here

# %% [markdown]
# 3.2 - Take a look at Alabama's values for these two variables (`PITHomeless` and `SubstanceAbuse`). What do they mean?

# %% [markdown]
# 3.3 - To get the full picture, we need to look at data from all 50 states. Let’s make a visualization to explore this model: `PITHomeless` = `SubstanceAbuse` + Other Stuff

# %%
#make a visualization here

# %% [markdown]
# 3.4 - Based on your visualization, what do you think of this hypothesis?

# %% [markdown]
# 3.5 - Based on this, what would your prediction for `PITHomeless` be for a hypothetical state that had a very high `SubstanceAbuse` percentage? How about for a low `SubstanceAbuse` state?

# %% [markdown]
# ## 4.0 - Exploring `PITHomeless` = `HouseholdIncomeK` + Other Stuff.

# %% [markdown]
# 4.1 - Let's use some code to look at the first 6 rows of this data set. This data has a lot of variables in it. Can we can combine head() and select() to look at the first 6 rows of only the variables `State`, `PITHomeless`, and `HouseholdIncomeK`? Try it!

# %%
#try it here

# %% [markdown]
# 4.2 - Take a look at Alabama's values for these two variables (`PITHomeless` and `HouseholdIncomeK`). What do they mean?

# %% [markdown]
# 4.3 - 3.3 - To get the full picture, we need to look at data from all 50 states. Let’s make a visualization to explore this model: `PITHomeless` = `HouseholdIncomeK` + Other Stuff

# %%
#make a visualization here

# %% [markdown]
# 4.4 Based on your visualization, what do you think of this hypothesis?

# %% [markdown]
# 4.5 - Based on this, how would you adjust your prediction of `PITHomeless` for a hypothetical state that had a very high `HouseholdIncomeK` percentage? How about for a low `HouseholdIncomeK` state?

# %% [markdown]
# ## 5.0 - Exploring `PITHomeless` = `MedianRent` + Other Stuff

# %% [markdown]
# 5.1 - Let's use some code to look at the first 6 rows of this data set. This data has a lot of variables in it. Can we can combine head() and select() to look at the first 6 rows of only the variables `State`, `PITHomeless`, and `MedianRent`? Try it!

# %%
#try it here

# %% [markdown]
# 5.2 - Take a look at Alabama's values for these two variables (`PITHomeless` and `MedianRent`). What do they mean?

# %% [markdown]
# 5.3 - To get the full picture, we need to look at all 50 states. Let’s make a visualization to explore this model: some of the variation in the percentage `PITHomeless` is explained by `MedianRent`. Create a visualization to explore this model.

# %%
#make a visualization here

# %% [markdown]
# 5.4 - Based on your visualization, what do you think of this hypothesis?

# %% [markdown]
# 5.5 - Based on this, how would you adjust your prediction of `PITHomeless` for a hypothetical state that had a very high `MedianRent`? How about for a low `MedianRent` state?

# %% [markdown]
# ## 6.0 - Comparing our Three Models

# %% [markdown]
# 6.1 - From looking at the three visualizations, which variable seems to explain more variation in `PITHomeless`: `SubstanceAbuse`, `HouseholdIncomeK` or `MedianRent`? What aspect of the visualizations are you looking at to make that judgment?

# %% [markdown]
# 6.2 - If states want to reduce homelessness, do you think they should pursue a policy that lowers median rent or lowers household income? Why?

# %% [markdown]
# 6.3 - Is "explain variation" the same as "cause variation"? What is the difference?

# %% [markdown]
# ## 7.0 - Further reading about this topic

# %% [markdown]
# - If you are interested in further reading on homelessness and rent prices, check out
# this article: https://www.pewtrusts.org/en/research-and-analysis/articles/2023/08/22/how-housing-costs-drive-levels-of-homelessness
#
# - And this one on experiments that increased income of homeless individuals: https://schalkenbach.org/basic-income-for-the-homeless-findings-from-three-experiments/
#
# - On housing costs and homelessness: https://schalkenbach.org/in-a-good-economy-homelessness-goes-up-the-paradox-of-progress-and-poverty/
