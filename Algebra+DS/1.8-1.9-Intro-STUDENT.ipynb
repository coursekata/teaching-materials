# %% [markdown]
# # Wrangling Data
# ## Chapter 1.8 - 1.9 Intro

# %%
# This code will load the R packages we will use
suppressPackageStartupMessages(library(coursekata))

# set styles
css <- suppressWarnings(readLines("https://raw.githubusercontent.com/jimstigler/jupyter/master/ck_jupyter_styles_v2.css"))
IRdisplay::display_html(sprintf('<style>%s</style>', paste(css, collapse = "\n")))

# Load the data from a google csv file
elections <- read.csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vR7kS5Bj2sf-FVKQXz7lm4s1RTyn7Zbebv0upxBGCyW7MeQrEiyZLRb9vDUHPIW2PicFXMWcnpJunuH/pub?output=csv")

mini_elections <- elections[c(1, 3, 5, 10, 12, 23, 36, 44, 50), c(1, 3, 4, 8, 10, 11, 12)]

# What emoji will this be?
print("\U0001F920")

# %% [markdown]
# ### The Dataset
#
# **Description:** The `mini_elections` data frame contains the data printed on your paper data frames. The dataset has tidy organization, with one row per state.
#
# #### Variables
#
# - `state`: Name of the state
# - `r_votes16`: Number of votes for the Republican presidential candidate in 2016
# - `d_votes16`: Number of votes for the Democratic presidential candidate in 2016
# - `total_votes16`: Total number of votes cast in the 2016 presidential election (Republican + Democratic votes)
# - `house_seats`: Number of representatives the state sends to the U.S. House of Representatives. This number depends on the state's population.
# - `senate_seats`: Number of U.S. Senators from the state. Every state has 2 senators, no matter how big or small.
# - `electoral_votes`: Total number of votes the state gets in the Electoral College (used to choose the President). This is equal to the number of House seats + 2 Senators.
#
# #### Data Sources
#
# - **Election Results Data:** MIT Election Data and Science Lab, 2017, ["U.S. President 1976–2020"](https://doi.org/10.7910/DVN/42MVDX), Harvard Dataverse, V6
# - **Electoral College Info:** [archives.gov](https://www.archives.gov/electoral-college/allocation)

# %% [markdown]
# ## 1.0: `filter()`
#
# ### 1.1 Show with your physical data frame what the two commands below might do:
#
# `filter(mini_elections, state == "HAWAII")`
#
# `high_electoral <- filter(mini_elections, electoral_votes > 15)`
#
# ### 1.2 Explain what each line of code does.

# %% [markdown]
# *type your response here*

# %% [markdown]
# ### 1.3 What do these filters help you notice about the data?
#
# What question(s) could these filters help answer?

# %% [markdown]
# *type your response here*

# %% [markdown]
# ## 2.0: `select()`
#
# ### 2.1 Show with your physical data frame what the two commands below might do:
#
# `select(mini_elections, state, r_votes16, d_votes16)`
#
# `select_votes <- select(mini_elections, state, total_votes16, electoral_votes)`
#
# ### 2.2 Explain what each line of code does.

# %% [markdown]
# *type your response here*

# %% [markdown]
# ### 2.3 Why might someone want to use `select()`?
# What does it help you see or focus on?

# %% [markdown]
# *type your response here*

# %% [markdown]
# ## 3.0: `arrange()`
#
# ### 3.1 Show with your physical data frame what the two commands below might do:
#
# `arrange(mini_elections, -electoral_votes)`
#
# `arranged_votes <- arrange(mini_elections, d_votes16)`
#
# ### 3.2 Explain what each line of code does.

# %% [markdown]
# *type your response here*

# %% [markdown]
# ### 3.3 What patterns does this help reveal?
# What kinds of questions or comparisons does it help you make?

# %% [markdown]
# *type your response here*

# %% [markdown]
# ## 4.0: Try It Out in Code
# ### 4.1 Use the blank code cell below to see if the output matches what you did on paper.
# try your own command using `select()`, `filter()`, and a`arrange()`.

# %%
#Write your filter() code here:

# %%
# Write your select() code here:

# %%
# Write your arrange() code here:

# %% [markdown]
# ### 4.2 Make up your own commands.
#
# Create new commands using variables you're curious about.
#
# See what happens when you combine more than one command!

# %%
# write some code here

# %% [markdown]
# <div class="discussion-question">
#
# ### 4.3 Discussion
# What did the different code functions help you notice? What patterns or surprises did you see? How might someone else filter or sort this data to answer a totally different question?
