# %% [markdown]
# # Chapter 2 Investigation Notebook: Modeling State Data with Functions

# %%
# This code will load the R packages we will use
suppressPackageStartupMessages({
    library(coursekata)
})

# set styles
css <- suppressWarnings(readLines("https://raw.githubusercontent.com/jimstigler/jupyter/master/ck_jupyter_styles_v2.css"))
IRdisplay::display_html(sprintf('<style>%s</style>', paste(css, collapse = "\n")))

# Load data
States <- read.csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vS_JNYSbto8twkSMduBji9ZMukatrlxKpbqJGj7lRZBviw0qbQncPWcamcJcrthKdong-jma5GP1nQl/pub?output=csv") %>%
     select(-c(ShelteredPITHomeless, UnshelteredPITHomeless, PITHomeless))

head(States)

# %% [markdown]
# ## 1.0: Explore Variation

# %% [markdown]
# ### 1.1 Explore the variables.
# The data set `States` has 50 rows, each row representing a state. The list of variables is long (57 variables). Your teacher will give you a set of cards that has all of the variables. Use the variable cards to sort the variables into groups that make sense to you.
#
# ### How did you decide to group them?

# %% [markdown]
# *Explain your group's sorting here*

# %% [markdown]
# ### 1.2 Explore the `States` data frame
#
# Use some code below to look at the data frame -- use commands like `select`, `filter`, and `arrange` to explore.

# %%
# write some code here

# %% [markdown]
# *Jot your ideas here*

# %% [markdown]
# ### 1.3 Outcomes and Hypotheses
#
# Back to the variable cards from **1.1**. Choose one or two variables that could be outcomes. Which other variables might help explain or predict those outcomes? Why?
#
# ### Write a few possible hypotheses as word equations.
# (For example: Obesity ~ PovertyRate)

# %% [markdown]
# *Jot your ideas here*
#
# Hypothesis 1
# Word Equation:
# Function Notation:
# Explanation:
#
# Hypothesis 2
# Word Equation:
# Function Notation:
# Explanation:
#
# *You can add more hypotheses to this cell*

# %%
# you can also write some code to visualize your hypotheses

# %% [markdown]
# <div class="discussion-question">
#
# ### 1.4 Discussion: Deciding a Class Outcome Variable
# As a class, decide on one outcome variable that feels important or interesting to predict.
# - Each group or individual will then choose their own predictor variable to go with this outcome.
# - Your group will write a hypothesis and create a scatterplot with a line of best fit.
#
# Later, we’ll compare across groups to see how different predictors relate to the same outcome.

# %% [markdown]
# *Class Outcome Variable:*

# %% [markdown]
# ## 2.0: Your Hypothesis

# %% [markdown]
# ### 2.1 Choose a Predictor
#
# Now that we’ve chosen a class outcome variable, your group will select a predictor variable that you think might be related to it.
#
# ### What predictor variable did your group choose, and why do you think it might be related to the outcome?

# %% [markdown]
# *write your response here*

# %% [markdown]
# ### 2.2 Write your hypothesis as a word equation and function notation that connects your predictor to the class outcome.

# %% [markdown]
# *write your word equation here*

# %% [markdown]
# *write your function notation here*

# %% [markdown]
# ### 2.3 Visualize Your Hypothesis

# %%
# write some code here to make a scatter plot of your hypothesis

# %% [markdown]
# ### Interpret what you see
# - What overall pattern or trend do you see in your scatterplot?
# - Does the relationship look mostly positive, negative, or flat? Or is it unclear?
# - If you were to draw a straight line, where would it start and how steep would it be?

# %% [markdown]
# *write your response here*

# %% [markdown]
# ## 3.0 Modeling Variation

# %% [markdown]
# ### 3.1 Create a linear model for your hypothesis.
# Add a linear model to your scatter plot of your hypothesis

# %%
# write some code here

# %% [markdown]
# ### 3.2 Write the equation for your model.
#
# Write your linear model as an equation: `Outcome`= $𝑏_0$ + $b_1$*`Predictor` + Error

# %% [markdown]
# *write your equation here*

# %% [markdown]
# ### 3.3 What are your $b_0$ and $b_1$?
# What values did you pick for your $b_0$ and $b_1$ and how did you decide on or calculate them?

# %% [markdown]
# *write your response here*

# %% [markdown]
# ### 3.4 Interpreting Your Model
#
# In context, what does the slope mean? What does the intercept mean? Does the intercept make sense in the real world for your variables? Why or why not?

# %% [markdown]
# *write your response here*

# %% [markdown]
# ## 4.0 Using your model

# %% [markdown]
# ### 4.1 If you haven't already, program your model as a custom function in R.
#
# Then use `gf_function()` to put your line on your scatterplot.

# %%
#write some code here

# %% [markdown]
# ### 4.2 Use your custom function to generate a few predictions.
# Where will those predictions appear on our scatterplot? **Add the predictions to your scatterplot.**

# %%
#write some code here

# %% [markdown]
# ### 4.3 Explain how your custom function is calculating the three predicted outcomes.

# %% [markdown]
# *write your response here*

# %% [markdown]
# ### For each prediction you made...
# - Write a function notation statement for the predicted point.
# - Explain what the prediction means in context.
# - Does this seem reasonable compared to the data?

# %% [markdown]
# *write your response here*

# %% [markdown]
# ### 4.4 What is the domain and range of your function?

# %% [markdown]
# *write your response here*

# %%
# you can also write some code

# %% [markdown]
# ## 5.0: Other Models from Class

# %% [markdown]
# ### 5.1 Share Your Model
#
# Your group will prepare a short presentation to share your model with the class.
#
# Include the following in your presentation:
# - Your hypothesis (word equation).
# - Your scatterplot with the line you created.
# - Your linear equation with slope ($b_1$) and intercept ($b_0$).
# - Interpretation of slope and intercept in context.
# - One or two predictions from your custom function — explain what they mean and whether they are reasonable.
# - Domain and range of your model — when does it make sense, and when does it not?
#
# Be ready to explain your choices and compare your results to the class outcome as a whole.

# %% [markdown]
# ### 5.2 Comparing Models
#
# After listening to your classmates’ presentations, answer the questions below:
# - Write down one or two interesting models that your classmates explored.
# - How does your model compare to theirs in terms of strength (stronger, weaker, about the same)?
# - How does your model compare in terms of direction (positive, negative, no clear trend)?
# - Was there a model that seemed to predict the outcome better than yours? Why do you think so?
# - Was there a relationship that looked really different from yours? What made it stand out?

# %% [markdown]
# *jot your ideas below*

# %% [markdown]
# ### 5.3 Reflection
# - Take a moment to reflect on what you learned from exploring and comparing models.
# - What did you learn about your outcome variable from looking at many different predictors?
# - What did you notice about how slope and intercept can change depending on the predictor?
# - What’s one new question or idea you have after seeing your classmates’ models?

# %% [markdown]
# *jot your ideas below*

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=69160fbc-ed07-4747-a631-40af8243d52c' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
