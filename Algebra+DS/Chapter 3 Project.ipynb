# %% [markdown]
# # <center>Chapter 3 Project: Which Colleges Are Worth It? </center>

# %%
# Load the CourseKata library
suppressPackageStartupMessages({
    library(coursekata)
})

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# ## Link to Guide and Rubric
#
# The **Guide** answers the question "What is a data analysis report?" and the **Rubric** can be used to help you write a good data analysis report.
#
# You can access both the guide and the rubric at this link: https://bit.ly/data-analysis-report-guide
#
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# ## Data
#
# The data set `colleges` has over 1,000 rows, each row representing a four-year university, and 26 variables. You can read about each variable [here](https://docs.google.com/document/d/1UgG4WYHskzSwc53wKK1qsDj74yVlfcifct3jO8adBrA/edit?usp=sharing)
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# ## Instructions
#
# Imagine you’ve been asked to help students and families answer a big question:
# **Which colleges are worth the price?**
#
# You’re contributing a short **data-driven report** to a national student advising guide. Your job is to use real college data to explore whether certain colleges offer better value than others — for example, do students at higher-priced colleges actually earn more or graduate at higher rates? Or are there some colleges that seem to "punch above their weight"?
#
# The organization has given you access to a dataset with information on over 1,000 U.S. colleges and universities. You’ll use this data to test a hypothesis about what might predict student outcomes — such as earnings, graduation rate, or student loan default rate — and decide whether cost is a good predictor of value.
#
# Your report should include:
#
# > - An **introduction** that explains the problem, the data, and your hypothesis (clearly state your outcome variable and one explanatory variable).
# > - A **word equation** and a **graph** that show the relationship you are exploring.
# > - A **linear model** written as an equation.
# > - **Predictions** from your model, explained in context.
# > - An interpretation of the **domain and range** — when does your model make sense, and when doesn’t it?
# > - A short **reflection** on what your model reveals, and its strengths and limitations. Did it help you answer the question of value?
# >
# Think of this as telling a **story with data**: Based on the model you built, what would you advise a student to consider when comparing college options?
#
#
# </div>

# %%
# Load data
colleges <- read.csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vRSCbBDGKuckuHwWg0H6tlXat6gvWzKTyqnkUAw_oyXTBVhDgK5aSzWggLXXEjaFp-tT7SsBIXxHCxi/pub?output=csv')

# Write some code to look at the data frame

# %% [markdown]
# ## Intro/Overview of the Problem or Question

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# The goal of this section is to provide an overview of the context, situation, or problem.
#
# A good introduction section typically includes the following topics (but not necessarily in this order):
#
# - A description of the question or problem you are investigating and why this question is important
#
# - A description of the data you will use in your investigation, such as:
#   - where the data came from
#   - why and how it was collected
#   - what cases and variables are included
#
# - Your initial hypothesis (perhaps also stated as a word equation), specifying outcome and explanatory variables, and why you think your hypothesis is plausible
#
# </div>

# %% [markdown]
# ## Explore Variation

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# The goal of this section is to explore variation in your explanatory and outcome variables. That exploration will almost certainly include visual displays of your data.
#
# A good exploring variation section typically includes the following topics (but not necessarily in this order):
#
# - A description of how you cleaned and prepared your data and why, such as:
#   - filtering cases
#   - handling missing data
#   - recoding or creating new variables
# - Visualizations or tables to explore the distributions of relevant variables and hypothesized relationships among variables
# - Descriptions of the visualizations or tables, and explanations of how they relate to the hypotheses or research questions
# - You can incorporate multiple variables here! (hint: `color = ~(variable)`)
#
# </div>

# %% [markdown]
# *Write your word equation here*

# %% [markdown]
# *Explain your word equation*

# %%
# create a visualization using gf_point here

# %% [markdown]
# *Explain your visualization*

# %% [markdown]
# ## Model Variation

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# The goal of this section is to build a linear model that explains some of the variation in your outcome variable.
#
# A good modeling section should include:
# - Your model written as an equation (using slope and intercept).
# - A graph of your model (scatterplot + line).
# - An explanation of what the slope and intercept mean in the context of your variables.
# - A few predictions from your model (include them on your graph too), with an explanation of what they mean.
# - A discussion of the domain and range: when your model makes sense, and when it doesn’t.
#
# > Remember, now you know how to find the *best* linear model!
#
# </div>

# %%
# create a visualization using gf_point and create a linear model here

# %% [markdown]
# *Write the equation for your linear model*

# %% [markdown]
# *Interpret the slope and intercept of your model*

# %% [markdown]
# *Make some predictions using your model. Write them using function notation and explain what they mean.*

# %% [markdown]
# ## Evaluate Your Model

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Now that you've built a linear model, it's time to **evaluate how well it actually fits the data**. This section is about looking at how close your predictions are to the real outcomes, and thinking about how useful your model really is.
#
# Use what you’ve learned about **residuals** and **measures of error** (RMSE and PRE) to explore model accuracy and reflect on what your model can (and can’t) explain.
#
# A strong evaluation section should include:
#
# - A **definition of residuals** and why they matter.
# - Code that calculates measure of error.
# - A discussion of:
#   - When your model **overestimates** or **underestimates**.
#   - What the measures of error mean.
#   - What all of this says about how well your model fits.
#
# > Remember: A good model doesn't need to be perfect — it just needs to help us make better predictions than guessing!
#
# </div>

# %% [markdown]
# *Explain the residuals (you might want to calculate a few as an example)*

# %%
# write some code here

# %% [markdown]
# *Explain how well your model fits the data*

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# ## Bonus: Use Models to Make a Comparison

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# The goal of this section is to make models of only certain subsets of your data (like comparing private vs. public, comparing a couple different states, comparing one state or type of college to the average, etc.).
#
# In this section, `filter` your data set and create models. You should include a graph and explaination or interpretation.
#
# </div>

# %%
# filter your data use this format: new_name <- filter(colleges, rule)


#example: private <- filter(colleges, ownership == "Private")

# %%
# find the best linear models for your subsets

# %%
# create a visualization that shows all of your models

# %% [markdown]
# *Explain your visualization here.*

# %% [markdown]
# ## Conclusions

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# The goal of this section is to wrap up your project by showing your audience the “big picture” of what you discovered.
#
# A strong conclusion should include:
# - A short summary of what you set out to do, the model you built, and what you found.
# - An explanation of what your results mean in relation to the original question.
# - A reflection on the **implications** of your findings: what can someone learn or take away from your analysis?
#
# Remember: your conclusion should make sense to someone **outside our class** who hasn’t seen all your work. Think of it as telling the ending of the story you started.
#
# </div>

# %% [markdown]
# *type your response here*

# %% [markdown]
# ## Limitations

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# The goal of this section is to reflect on the **limits of your model**, so your audience understands when to be cautious about your results.
#
# A strong limitations section might include:
#
# - **When does your model not make sense?**
# - Think about the **domain and range** of your model.
# - Are there predictions that don’t seem realistic (e.g., negative earnings, extremely high values)?
#
# - **What might be missing?**
#    - Are there other factors that could help explain the outcome that you didn’t include?
#      (For example: student major, location, selectivity, or job market conditions.)
#
# - **What are the limits of the data?**
#    - The data is **institution-level**, not about individual students. How does that affect how we interpret your model?
#    - Some colleges may report data from different years or use different definitions. Could that affect consistency?
#    - What do you notice about missing data or unusual values?
#
# >  Remember: Pointing out limitations doesn’t weaken your project — it shows that you’re thinking like a data scientist. Good models help us make better decisions, but they don’t tell the whole story.
#
#
# </div>

# %% [markdown]
# *type your response here*

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=69160fbc-ed07-4747-a631-40af8243d52c' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
