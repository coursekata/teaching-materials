# %% [markdown]
# # Chapter 1 Investigation Notebook: Explaining Variation in Fictional Characters

# %%
# This code will load the R packages we will use
suppressPackageStartupMessages({
    library(coursekata)
})

# set styles
css <- suppressWarnings(readLines("https://raw.githubusercontent.com/jimstigler/jupyter/master/ck_jupyter_styles_v2.css"))
IRdisplay::display_html(sprintf('<style>%s</style>', paste(css, collapse = "\n")))

# What emoji will this be?
print("\U0001F984")
# Out:
# <style><style>
# /* Force CSS block parsing */
# .teacher-note::before {
#     content: "";
#     display: none;
# }
#
# /* Teacher Notes */
# .teacher-note {
#     border: 3px dashed #fd7f91;
#     font-size: 14px;
#     color: #000000;
#     background-color: #ffe8ec;
#     padding: 10px;
#     border-radius: 5px;
#     line-height: 1.5;
# }
# .teacher-note ol, .teacher-note ul, .teacher-note li {
#     margin-top: 5px;
#     padding-left: 20px;
#     color: #000000;
# }
# .teacher-note code {
#     color: #000000;
#     background-color: #ffd3da;
# }
#
# /* Discussion Question */
# .discussion-question {
#     border: 3px solid #a88bd4;
#     font-size: 14px;
#     color: #000000;
#     background-color: #eee8f6;
#     padding: 10px;
#     border-radius: 5px;
#     line-height: 1.5;
# }
# .discussion-question h3 {
#     margin: 0; /* Remove top and bottom margin */
#     padding: 0; /* Ensure no padding is applied */
# }
# .discussion-question h3:first-child {
# ...

# %% [markdown]
# ## 1.0: Explore the Data Frame
# Let's get familiar with the larger data set we will be working with. Run the code below to take a look at a few characters (one character is represented in each row).

# %%
# Loads the data frame from a google sheet
characters <- read.csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vQk_n4m-VBCD7CtcpB1kOsiNDLrPmEOEtlOoaKwDhogE_YeGEW5PYTaOtZaqypEgHRFGWsZ0pdYvt_A/pub?gid=0&single=true&output=csv")

# Prints out a sample of 5 rows of this data frame
sample(characters, 5)

# %% [markdown]
# ### 1.1 Note anything interesting to you, or that you are curious about, or anything you think we might want to know about the data frame, the characters, or the variables.

# %% [markdown]
# *type your resposne here*

# %% [markdown]
# ### The Dataset
#
# **Description:** The `characters` data frame contains characters from various fictional universes. At [Open Psychometrics](https://openpsychometrics.org/tests/characters/), more than 3 million volunteers from the internet rated these characters on various traits by using a sliding scale. For example, the character Mushu (from Disney's Mulan), is depicted below being rated on a scale from zero, rude, to 100, respectful. These ratings have been averaged to produce the data frame `characters`.
#
# <img src="https://i.postimg.cc/tXVg4SjZ/rating-characters.png" alt="example of how people rated a character with a slider" width = 40%>
#
# ##### Variable Descriptions
#
# - `char_id` The character ID.
# - `char_name` The character's name.
# - `uni_id` The universe ID for the book, game, movie, or TV show.
# - `uni_name` The universe name of the book, game, movie, or TV show.
# - `gender` The gender of the character (M=Male, F=Female, NB=NonBinary).
#
#
# - `abstract` A rating of how abstract (vs concrete) the character is on a scale of 0-100 (0-concrete, 100-abstract).
# - `agreeable` A rating of how agreeable (vs stubborn) the character is on a scale of 0-100 (0-stubborn, 100-agreeable).
# - `anxious` A rating of how anxious (vs calm) the character is on a scale of 0-100 (0-calm, 100-anxious).
# - `attractive` A rating of how attractive (vs repulsive) the character is on a scale of 0-100 (0-repulsive, 100-attractive).
# - `beautiful` A rating of how beautiful (vs ugly) the character is on a scale of 0-100 (0-ugly, 100-beautiful).
# - `chaotic` A rating of how chaotic (vs orderly) the character is on a scale of 0-100 (0-orderly, 100-chaotic).
# - `chill` A rating of how chill (vs offended) the character is on a scale of 0-100 (0-offended, 100-chill).
# - `cool` A rating of how cool (vs dorky) the character is on a scale of 0-100 (0-dorky, 100-cool).
# - `decisive` A rating of how decisive (vs hesitant) the character is on a scale of 0-100 (0-hesitant, 100-decisive).
# - `emotional` A rating of how emotional (vs unemotional) the character is on a scale of 0-100 (0-unemotional, 100-emotional).
# - `extrovert` A rating of how extroverted (vs introverted) the character is on a scale of 0-100 (0-introvert, 100-extrovert).
# - `feminine` A rating of how feminine (vs masculine) the character is on a scale of 0-100 (0-masculine, 100-feminine).
# - `future_focused` A rating of how future-focused (vs present-focused) the character is on a scale of 0-100 (0-present-focused, 100-future-focused).
# - `loveable` <mark>A rating of how loveable (vs punchable) the character is on a scale of 0-100 (0-punchable, 100-loveable).</mark>
# - `messy` A rating of how messy (vs neat) the character is on a scale of 0-100 (0-neat, 100-messy).
# - `moody` A rating of how moody (vs stable) the character is on a scale of 0-100 (0-stable, 100-moody).
# - `open_minded` A rating of how open-minded (vs close-minded) the character is on a scale of 0-100 (0-close-minded, 100-open-minded).
# - `reasoned` A rating of how reasoned (vs instinctual) the character is on a scale of 0-100 (0-instinctual, 100-reasoned).
# - `respectful` A rating of how respectful (vs rude) the character is on a scale of 0-100 (0-rude, 100-respectful).
# - `self_assured` A rating of how self-assured (vs self-conscious) the character is on a scale of 0-100 (0-self-conscious, 100-self-assured).
# - `self_disciplined` A rating of how self-disciplined (vs disorganized) the character is on a scale of 0-100 (0-disorganized, 100-self-disciplined).
# - `tall` A rating of how tall (vs short) the character is on a scale of 0-100 (0-short, 100-tall).
# - `trusting` A rating of how trusting (vs suspicious) the character is on a scale of 0-100 (0-suspicious, 100-trusting).
#
#
# ##### Data Source:
#
# Originally collected at [Open Psychometrics](https://openpsychometrics.org/tests/characters/) made available by Tanya Shapiro as a [Tidy Tuesday data set](https://github.com/rfordatascience/tidytuesday/tree/master/data/2022/2022-08-16).

# %% [markdown]
# ### 1.2 Explore a Character
#  **Run** the code below to see the personality trait scores for one character. If you get a character that you don't know, you can run the code again to get a new character. You might have to run it a LOT of times - that's okay! **Once you get a character you know, answer the questions below.**

# %%
# This code prints out a sample of 1 row of this data frame
sample(characters, 1)
# Out:
#     char_id char_name      uni_id uni_name    gender abstract agreeable anxious
# 868 WV1     Wanda Maximoff WV     WandaVision F      68.3     39        77.6
#     attractive beautiful ⋯ messy moody open_minded reasoned respectful
# 868 89.2       96        ⋯ 52.8  83.5  53.1        20.9     63.7
#     self_assured self_disciplined tall trusting orig.id
# 868 43.2         46.9             47.5 44.8     868

# %% [markdown]
# ### What character did you get? What universe are they from?

# %% [markdown]
# *Type your response here*

# %% [markdown]
# ### What trait had the *highest* score? Explain that means. Why might people have scored this way?

# %% [markdown]
# *Type your response here*

# %% [markdown]
# ### What trait had the *lowest* score? Explain that means. Why might people have scored this way?

# %% [markdown]
# *Type your response here*

# %% [markdown]
# ### Are you *surprised* by any of the scores? Are there any that you disagree with?

# %% [markdown]
# *Type your response here*

# %% [markdown]
# ## 2.0: Explore Variation in `loveable`
# We’re interested in understanding what makes a character more or less loveable. Let’s start by looking at the extremes in the data.
# ### 2.1 Use the `arrange()` code to sort the `characters` data frame by characters' `loveable` score.

# %%
#write some code here

# %% [markdown]
# ### 2.2 Take a look at the characters at both ends of the spectrum. What kinds of characters show up at the top? At the bottom?

# %% [markdown]
# *type your reponse here*

# %% [markdown]
# ### 2.3 Based on what you observe, come up with three possible explanations for what makes a character more loveable.
#
# For each one:
# - Write a word equation to describe your hypothesis (outcome = explanatory + other stuff)
# - Use function notation to express your hypothesis (outcome = f(explanatory) + other stuff)
# - Explain your thinking. Why do you believe this variable might help explain why a character is more or less loveable?

# %% [markdown]
# *type your reponse here:*
# Hypothesis 1
# Word Equation:
# Function Notation:
# Explanation:

# %% [markdown]
# *type your reponse here:*
# Hypothesis 2
# Word Equation:
# Function Notation:
# Explanation:

# %% [markdown]
# *type your reponse here:*
# Hypothesis 3
# Word Equation:
# Function Notation:
# Explanation:

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# #### For the next section, **you will be assigned to work in groups on one of the 3 hypotheses**. Work on your assigned model first. If you have more time, try the other models.

# %% [markdown]
# ## 3.0 - Exploring `loveable` = `respectful` + Other Stuff.
# Let’s explore whether a character’s respectfulness helps explain how loveable they are.

# %% [markdown]
# ### 3.1 Let's use some code to look at the first 6 rows of this data set.
# This data has a lot of variables in it. Can we can combine head() and select() to look at the first 6 rows of only the variables `char_name`, `loveable`, and `respectful`? Try it!

# %%
#try it here

# %% [markdown]
# ### 3.2 Take a look at Michael Bluth's values for these two variables (`loveable` and `respectful`). What do they mean?

# %% [markdown]
# *type your response here*

# %% [markdown]
# ### 3.3 To get the full picture, we need to look at data from all *all* of the characters. Let’s make a visualization to explore this model: `loveable` = `respectful` + Other Stuff

# %%
#make a visualization here

# %% [markdown]
# ### 3.4 Based on your visualization, what do you think of this hypothesis?
# What kind of relationship do you see between respectfulness and loveability? Is it strong? Weak? Positive? Negative?

# %% [markdown]
# *type your response here*

# %% [markdown]
# ### 3.5 Scar from *The Lion King* has a `loveable` score of `15.4` and a `respectful` score of `12.9`
# <img src="https://i.postimg.cc/qMBGYBns/image.png" width="20%" align="left" style="margin-right: 20px;"/>
#
# - What are the coordinates of Scar’s point on a scatter plot?
# - How would you express Scar's data in function notation?
# - Does Scar's point fit the pattern you'd expect if `loveable = f(respectful)`? Why or why not?

# %% [markdown]
# *type your response here*
#
# - (X, Y)
# - __ = f(__)
# -

# %% [markdown]
# ### 3.6  Suppose a new character has a `respectful` score of **75**.
#
# - Based on your scatterplot, what would you predict their `loveable` score to be?
# - Add this predicted point to your plot using `%>%` and `gf_point()`. Make sure you [color](https://bookdown.org/hneth/ds4psy/D.3-apx-colors-basics.html) the point so you can see it in your graph.
# - Write your prediction as a function statement: __ = f(__).
# - What does this prediction mean in the context of the data?

# %% [markdown]
# *type your response here*

# %% [markdown]
# ## 4.0 - Exploring `loveable` = `moody` + Other Stuff.
# Let’s explore whether how moody character is helps explain how loveable they are.

# %% [markdown]
# ### 4.1 Let's use some code to look at the first 6 rows of this data set.
# This data has a lot of variables in it. Can we can combine head() and select() to look at the first 6 rows of only the variables `char_name`, `loveable`, and `moody`? Try it!

# %%
#try it here

# %% [markdown]
# ### 4.2 Take a look at Michael Bluth's values for these two variables (`loveable` and `moody`). What do they mean?

# %% [markdown]
# *type your response here*

# %% [markdown]
# ### 4.3 To get the full picture, we need to look at data from all *all* of the characters. Let’s make a visualization to explore this model: `loveable` = `moody` + Other Stuff

# %%
#make a visualization here

# %% [markdown]
# ### 4.4 Based on your visualization, what do you think of this hypothesis?
# What kind of relationship do you see between respectfulness and loveability? Is it strong? Weak? Positive? Negative?

# %% [markdown]
# *type your response here*

# %% [markdown]
# ### 4.5 Scar from *The Lion King* has a `loveable` score of `15.4` and a `moody` score of `87.3`
# <img src="https://i.postimg.cc/qMBGYBns/image.png" width="20%" align="left" style="margin-right: 20px;"/>
#
# - What are the coordinates of Scar’s point on a scatter plot?
# - How would you express Scar's data in function notation?
# - Does Scar's point fit the pattern you'd expect if `loveable = f(moody)`? Why or why not?

# %% [markdown]
# *type your response here*
#
# - (X, Y)
# - __ = f(__)
# -

# %% [markdown]
# ### 4.6  Suppose a new character has a `moody` score of **25**.
#
# - Based on your scatterplot, what would you predict their `loveable` score to be?
# - Add this predicted point to your plot using `%>%` and `gf_point()`. Make sure you [color](https://bookdown.org/hneth/ds4psy/D.3-apx-colors-basics.html) the point so you can see it in your graph.
# - Write your prediction as a function statement: __ = f(__).
# - What does this prediction mean in the context of the data?

# %% [markdown]
# *type your response here*

# %% [markdown]
# ## 5.0 - Exploring `loveable` = `cool` + Other Stuff.
# Let’s explore whether how moody character is helps explain how loveable they are.

# %% [markdown]
# ### 5.1 Let's use some code to look at the first 6 rows of this data set.
# This data has a lot of variables in it. Can we can combine head() and select() to look at the first 6 rows of only the variables `char_name`, `loveable`, and `cool`? Try it!

# %%
#try it here

# %% [markdown]
# ### 5.2 Take a look at Michael Bluth's values for these two variables (`loveable` and `cool`). What do they mean?

# %% [markdown]
# *type your response here*

# %% [markdown]
# ### 5.3 To get the full picture, we need to look at data from all *all* of the characters. Let’s make a visualization to explore this model: `loveable` = `cool` + Other Stuff

# %%
#make a visualization here

# %% [markdown]
# ### 5.4 Based on your visualization, what do you think of this hypothesis?
# What kind of relationship do you see between respectfulness and loveability? Is it strong? Weak? Positive? Negative?

# %% [markdown]
# *type your response here*

# %% [markdown]
# ### 5.5 Scar from *The Lion King* has a `loveable` score of `15.4` and a `cool` score of `72.2`
# <img src="https://i.postimg.cc/qMBGYBns/image.png" width="20%" align="left" style="margin-right: 20px;"/>
#
# - What are the coordinates of Scar’s point on a scatter plot?
# - How would you express Scar's data in function notation?
# - Does Scar's point fit the pattern you'd expect if `loveable = f(cool)`? Why or why not?

# %% [markdown]
# *type your response here*
#
# - (X, Y)
# - __ = f(__)
# -

# %% [markdown]
# ### 5.6  Suppose a new character has a `cool` score of **75**.
#
# - Based on your scatterplot, what would you predict their `loveable` score to be?
# - Add this predicted point to your plot using `%>%` and `gf_point()`. Make sure you [color](https://bookdown.org/hneth/ds4psy/D.3-apx-colors-basics.html) the point so you can see it in your graph.
# - Write your prediction as a function statement: __ = f(__).
# - What does this prediction mean in the context of the data?

# %% [markdown]
# *type your response here*

# %% [markdown]
# ## 6.0 - Comparing our Three Models

# %% [markdown]
# ### 6.1 Let's look at all three hypotheses at the same time.
# Write code below to visualize each hypothesis using `gf_point()`

# %% [markdown]
# ### `loveable` = `respectful` + Other Stuff.

# %%
# write some code to visualize loveable = respectful + other stuff

# %% [markdown]
# ### `loveable` = `moody` + Other Stuff.

# %%
# write some code to visualize loveable = moody + other stuff

# %% [markdown]
# ### `loveable` = `cool` + Other Stuff.

# %%
# write some code to visualize loveable = cool + other stuff

# %% [markdown]
# ### 6.2 Looking at the three graphs above, which variable seems to have the strongest relationship with loveable — `respectful`, `moody`, or `cool`?
# - How can you tell? What do you notice about the shape or pattern of the points?
# - Are the relationships positive or negative?
# - Which variable(s) don’t seem to explain much about how loveable a character is?

# %% [markdown]
# *type your response here*

# %% [markdown]
# ## 7.0 - Explore other Relationships
# In this section, you'll experiment with different variables to see which ones help explain why some characters are more loveable than others.

# %% [markdown]
# ### 7.1 Try out different scatter plots
# Use `gf_point()` to explore how loveable relates to *other* variables. Try at least 2 or 3 different explanatory variables. You can also add `color = ~variable` to highlight even more patterns.

# %%
# write some code

# %% [markdown]
# ### 7.2 Reflect on your exploration.
# - What patterns did you notice in your scatterplot(s)?
# - Which variable(s) showed a strong relationship with loveable?
# - Were the relationships positive, negative, or unclear?
# - Did coloring by another variable help you notice anything new?

# %% [markdown]
# *type your response here*

# %% [markdown]
# ### 7.3 Choose your best hypothesis and write it as a word equation.

# %% [markdown]
# *type your response here*

# %% [markdown]
# ### 7.4 Designing a Loveable Character
# Imagine you're working on a new TV show. You want it to be a big hit — so you're proposing a character that audiences will find super loveable.
# - Based on the data you've explored, what kind of traits would your character have?
# - Which variables seem most important for predicting loveability?
# - Would your character be respectful? brave? funny? something else?
# - How are you using your data-based model to make your design decisions?
#
# Take a few sentences to describe the character you'd create and how the data informed your choices.

# %% [markdown]
# *type your response here*
