# %% [markdown]
# # Pokémon: Prepare For Battle (COMPLETE)
#
# ## Chapter 1.4-1.7 Overview Notebook

# %% [markdown]
# ### Welcome to the world of Pokémon (e.g., video games, card game, Pokémon Go, anime)!
#
# <img src="https://i.postimg.cc/wgQQYYyL/6-B-Various-Pokemon.jpg" title="varieties of pokemon"/>
#
# The Pokémon franchise, introduced originally as a Nintendo video game (1996), is all about catching, training, and battling with Pokémon (a Japanese shortening of “Pocket Monster"). Over the years, there have come to be over 800 fictional Pokémon species that range from animal-like to plant-like creatures, and even species based on inanimate objects (like *Klang* which looks like interlocking gears).
#
# There are eighteen different Types of Pokémon (such as Grass, Water, Fire, etc.) and each type has its own individual strengths and weaknesses. For instance, Grass is generally strong against Water, Water is usually strong against Fire, and Fire is generally strong against Grass (similar to the game “Rock, Paper, Scissors”).
#
# The goal of the game is to become the strongest Trainer by catching and training as many Pokémon as you can and battling them against your opponent’s Pokémon (hence, the slogan “Gotta catch 'em all!”). When you catch a Pokémon, they shrink down into poké balls that can fit in your pocket.

# %% [markdown]
# <div class="teacher-note">
#
# <b>Goals of this section:</b> In this lesson, students will explore how one variable might help explain or predict another — a foundational idea in both algebra and data science. They will learn to describe relationships between variables using functions, visual models, and word equations, and begin to reason about when a model is useful and when it’s not.
#
#   <ul>
#     <li> Students will distinguish between <i>explanatory</i> (input) variables and <i>outcome</i> (output) variables.
#     <li> Students will represent their hypotheses using word equations in the form: <b>Outcome = Explanatory + Other Stuff</b>, and begin using <b>function notation</b> like <code>total = f(speed) + other stuff</code> to express relationships.
#     <li> Students will reflect on how useful their chosen variable is for predicting the outcome, and understand that “other stuff” accounts for the unexplained variation in real-world data.
#     <li> Students will begin to reason about <i>domain and range</i> in real-world contexts, thinking about what values are possible or reasonable for both input and output variables.
#   </ul>
#
#   This lesson supports conceptual understanding of functions as models, while introducing flexible thinking about patterns, prediction, and unexplained variation — key ideas in data science.
# </div>

# %% [markdown]
# ## 1.0: Get to Know the `Pokemon` Data Frame
#
# Imagine you're a Pokémon trainer preparing for a major tournament. Your job is to predict how strong each Pokémon is overall, using what trainers call the `total` — a summary of how powerful a Pokémon is in battle.
#
# You’ve been given some information about each mystery Pokémon, including:
# - `type1` The Pokémon’s primary type (e.g., fire, grass, psychic)
# - `capture_rate`How easy or hard the Pokémon is to catch (lower = harder)

# %% [markdown]
# <div class="guided-notes">
#
# ### 1.1 Take a look at the head of a data set called `Pokemon` (it's also available in your guided notes). What do you think each of the other variables means?
#
# <img src="https://i.postimg.cc/RVrhvvt5/Screenshot-2025-07-15-at-4-15-32-PM.png"/>

# %% [markdown]
# *type your reponse here*

# %% [markdown]
# ### 1.2 Definitions of all the variables
#
# The data set includes the following:
# - `name`: The name of the Pokémon
# - `pokedex_number`: Its number in the National Pokédex
# - `type1`: A Pokémon’s main type (like Fire, Water, or Grass), which affects which moves it’s strong or weak against
# - `type2`: A second type (if it has one)
# - `num_type`: The number of types the Pokémon has (1 or 2)
# - `height`: The Pokémon’s height in meters (m)
# - `weight`: The Pokémon’s weight in kilograms (kg)
# - `capture_rate`: How easy or hard it is to catch the Pokémon (higher = easier)
# - `total`: The sum of all the stats listed below — a rough measure of how strong it is overall
# - `hit_points`: How much health it has (how much damage it can take before fainting)
# - `attack`: How strong it is with physical moves (like punches or tackles)
# - `defense`: How well it can block physical attacks
# - `sp_attack`: How strong it is with special moves (like Fire Blast or Thunderbolt)
# - `sp_defense`: How well it can block special moves
# - `speed`: How fast it is — faster Pokémon usually go first in battle
# - `generation`: Which generation of Pokémon games it was introduced in
# - `legendary`: Whether it's a Legendary Pokémon (super rare and usually very powerful)
# - `category`: A broad group for its type (like Elemental, Physical, or Mystic)
# - `magic`: Whether the Pokémon uses more “magical” or mysterious types and moves (True/False)
# - `friendship`: How naturally friendly the Pokémon is with its trainer — this affects how quickly it bonds in the games
# - `recommended_ball`: A suggestion for the kind of Poké Ball that would work well when trying to catch it
#
# This dataset was sourced from [Kaggle](https://www.kaggle.com/datasets/rounakbanik/pokemon?resource=download).

# %% [markdown]
# <div class="teacher-note">
#
# <b>Teacher Note:</b> You might want to spend a little time disucssing the different variables here. We are focusing on `total` as a measure of a Pokémon's overall strength. The other variables are different attributes that Pokémon have. Invite a student (or two) who is a Pokémon expert to explain the variables to the class.
#
# If you want to have a concrete example, use the code below to show Bulbasaur, a very popular Pokémon (just make sure you run the set up cell in 1.3 first).
# </div>

# %%
# show Bulbasaur (using the selected variables)
filter(Pokemon, name == "Bulbasaur") %>% 
    select(name, type1, magic, defense, capture_rate, speed, total)

# show Bulbasaur (using the whole dataframe)
filter(Pokemon, name == "Bulbasaur")

# %% [markdown]
# ### 1.3 Write some code to take a look at the `Pokemon` data frame.

# %%
# This code will load the R packages we will use
suppressPackageStartupMessages(library(coursekata))

# set styles
css <- suppressWarnings(readLines("https://raw.githubusercontent.com/jimstigler/jupyter/master/ck_jupyter_styles_v2.css"))
IRdisplay::display_html(sprintf('<style>%s</style>', paste(css, collapse = "\n")))

# Load the Pokemon data frame
Pokemon <- read.csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vR5daht3qBiR0p_WyLnh6XaepptTZHDUawNCVlyuu9-2wPPeBr_NvrCHG5Xv1EUUQsvq0UM2VwHexYi/pub?output=csv", head=TRUE)

# write code here

# What emoji will this be?
print("\U000026A1")

# %%
# COMPLETE

head(Pokemon)

glimpse(Pokemon)

# %% [markdown]
# ### 1.4 What's on each row of this data? What is in each column?

# %% [markdown]
# *type your response here*

# %% [markdown]
# ### 1.5 How many Pokémon are in this data set? (Would you count the rows or columns to find out?)

# %% [markdown]
# *type your response here*

# %% [markdown]
# <div class="discussion-question">
#
# **Optional Discussion Prompt:** Let's take a moment to talk about the dataset we're using.
# - How many rows (Pokémon) are in this dataset?
# - How many columns (variables) are we using?
# - Which variables are categorical (like a label or group)?
# - Which are quantitative (measured with numbers)?
# - Which ones do you think might be helpful for predicting `total`? Why? (We will find out in the next section when we try out some Pokémon battles)
#
# </div>

# %% [markdown]
# ## 2.0: Battle Using the `sample()` Function
#
# <img src="https://i.postimg.cc/sx1pJ1x6/pikachu.png">

# %% [markdown]
# Ok, now let's go into battle... pair up with a partner.
#
# For the sake of simplicity, we will simulate a one-on-one match-up (and for all of the Pokémon pros, we acknowledge that a round in the actual game is much more complex than this!).

# %% [markdown]
# <div class="teacher-note">
#
# <b>Teacher Note:</b> The rules of the pokebattle are essentially like the card game, War -- where players randomly draw a card and the higher value wins. This is an extremely simple way to battle Pokemon. Normally, players bring multiple Pokemon, and they compete in multiple rounds of specific attacks. If students raise this issue, you can have a brief discussion about how we are using the `Total` variable as a *proxy* for the outcome of a battle or for a pokemon's strength, but it is not perfect, and that's okay! In data science, we often have to purposefully simplify phenomena to make it easier to measure.
#
# You can also have students change the `sample()` code in 2.2 to sample 2 (or more) pokemon [`sample(Pokemon, 2)`] and they can *add* their total scores together for the battle. This is still a simplistic version of a pokemon battle, but might make it more interesting!
# </div>

# %% [markdown]
# ### 2.1 Use the  `sample()` command below.
# We’ll use the `sample()` function to randomly select a Pokémon from the `Pokemon` data frame — just like drawing a card in a game. This lets us simulate what it might be like to randomly meet a new Pokémon, and helps us explore **variation** in battle.
#
# Compare your pokemon to a partner's. Who's Pokémon would win (has a higher `total` value)?

# %%
sample(Pokemon, 1)

# %% [markdown]
# <div class="teacher-note">
#
# <b>Teacher Note:</b> Highlight that students should get different outputs when running the `sample()` function. This is different than commands like `head()` or `tally()` that they've used before. This is because `sample()` is *randomly* selecting a Pokémon from the data frame (just like randomly drawing a card from a Pokémon deck).
# </div>

# %% [markdown]
# Compare your's and your partner's Pokémon below:
# - What type of Pokémon did you each get?
# - Were any of your Pokémon special (`legendary` or `magic`)?
# - Who's Pokémon can take more damange (`hit_points`)?
# - Who's Pokémon is faster (`speed`)?
# - Who's Pokémon has stronger attacks (`attack`)?
# - Who's Pokémon is the strongest (`total`)?

# %% [markdown]
# *type your response here*

# %% [markdown]
# ### 2.2 The battle continues.
# Okay that was just practice. Now use the `sample()` function again (and as many times as you want) to continue to battle against your partner. Each player draws a Pokémon and compares their total strength. The Pokémon with the higher total wins the round!
#
# Use the markdown cell below to record the names and total strengths of the Pokémon you and your partner draw. After battling a few times, start thinking:
# - What makes a Pokémon more likely to win?
# - Are some stats more important than others?

# %%
# write your code

# %% [markdown]
# *Keep score here*

# %% [markdown]
# ### 2.3 Based on the battles you just ran, are there any variables that you think might help predict a Pokémon’s `total` (overall strength)?
#
# - Which variables seemed to matter most when a Pokémon won or lost?
# - Were there any variables that didn’t seem to matter as much as you expected?
#
# Write down 1–2 variables you think are related to total, and explain why.

# %% [markdown]
# *type your response here*

# %% [markdown]
# ### 2.4 Definition of outcome and explanatory variables
#
# Using past data to make predictions—like predicting how powerful a pokemon is—is something statisticians and data analysts do all the time. To do this well, it's important to understand the two roles that variables can play.
#
# The **outcome variable** (or *output*) is what you're trying to predict. There's usually just one.
#
# **Explanatory variables** (or *inputs*) are the other things you know about each observation that might help you make a better prediction of the outcome.

# %% [markdown]
# ### 2.5 What are your variables?
# Look back at your response to 2.3.
# - What is the **outcome** variable we're trying to predict?
# - Which variable(s) could be useful **explanatory** variables?

# %% [markdown]
# The outcome variable is _ because it's what we're trying to predict.

# %% [markdown]
# One possible explanatory variable is _ because _.

# %% [markdown]
# ### 2.6 Description of word equations
#
# Your hypothesis about how an explanatory variable might help to predict an observation's value on an outcome variable can be expressed as a word equation. You can think of word equations as *informal models* of the world. Word equations take the form:
#
# - **Outcome Variable = Explanatory Variable + Other Stuff**
#
# For example, one hypothesis might be that a Pokémon's weight might be related to their total strength. We could express this idea as:
#
# - **total = weight + Other Stuff**
# Write your hypothesis as a word equation below and add it to your guided notes.

# %% [markdown]
# <div class="discussion-question">
#
# ### 2.7 *Discussion Question:* Why do we include "Other Stuff" in a word equation?
#
# </div>

# %% [markdown]
# <div class="teacher-note">
#
# <b>Teacher Note:</b>
#
# - No model is perfect--this is an important idea in statistical modeling - so we include “Other Stuff” to represent all the factors that affect the outcome but aren’t captured by the explanatory variable.
# - A Pokemon's type might contribute to its total strength, but it won’t tell the whole story. Some electric Pokemon are very powerful, and others aren't. “Other Stuff” includes everything else like the hit points, speed, attack - anything else that might influence total
#
# </div>

# %% [markdown]
# <div class="guided-notes">
#
# ### 2.8 Write a word equation to represent your hypothesis for predicting a Pokémon's `total`.
#
# Use as the explanatory variable the variable you think will be most helpful in predicting a Pokémon's `total`.
#
# </div>

# %% [markdown]
# <div class="guided-notes">
#
# [outcome variable] = [explanatory variable] + other stuff
#
# </div>

# %% [markdown]
# <div class="guided-notes">
#
# ### 2.9 Use your hypothesis to match Pokémon to `total`. Here are the `total` values  for the six Pokémon: 500, 780, 195, 425, 634, 320
#
# Based on your hypothesis and the data in the table, fill in the empty `total` cells with your best guesses. Which `total` value do you think goes with which Pokémon?
#
# </div>
#
# </div>

# %% [markdown]
# <div class="teacher-note">
#
# <b>Teacher Note:</b> Now that students have defined the **outcome variable** and chosen potential **explanatory variables**, they’ll use their hypotheses to match each Pokémon to a total value.
#
# - This is a prediction task — guided by reasoning and pattern-finding.
# - Students may come up with different ideas (e.g., “Speed matters most” or “Capture rate is key”). That’s okay — encourage diversity in approaches.
# - You can assign different explanatory variables to different groups or pairs (e.g., one group focuses on speed, another on defense, etc.). Afterward, groups can compare their guesses and see whose variable predicted best.
# - Most students will notice: predicting total is **hard**, but not random.
#   - Speed appears useful — the fastest Pokémon (140) has the highest total (780), but others vary.
#   - Capture rate shows a strong inverse trend: the hardest to catch has the highest total.
#   - Defense is trickier — two Pokémon have the same defense (78) but very different totals (500 vs. 634).
#   - Type1 and magic are less helpful — patterns aren’t obvious.
#
# Keep the debrief quick — the goal is to notice that some variables relate to total better than others, and to set up why we use modeling tools to find patterns more reliably.
#
# </div>

# %% [markdown]
# <div class="guided-notes">
#
# ### 2.10 Write down the definition of "explain variation".
#
# > <span style="font-size: 20px;">If we know a case’s value on one variable, we can make a better prediction of its value on another variable.</span>
#
# </div>

# %% [markdown]
# ### 2.11 When you filled in the missing values, how did knowing a Pokémon's value on the explanatory variable help you make a better guess as to its `total`?

# %% [markdown]
# <div class="teacher-note">
#
# <b>Sample Responses:</b>
#
# - I used `speed` as the explanatory variable, so I gave the highest `total` to the Pokémon with the highest speed. I figured faster Pokémon are stronger overall.
# - I picked `capture_rate` as my explanatory variable. Since lower capture rates usually mean a Pokémon is harder to catch, I assumed those would have higher `total` values.
#
# Encourage students to reference their word equation and make clear connections between the variable they chose and the predictions they made.
#
# </div>

# %% [markdown]
# ## 3.0 What makes a good predictor?
#
# Let's explore the following hypothesis:
# #### We can predict how strong a Pokémon is (`total`) by its `speed`.

# %% [markdown]
# <div class="teacher-note">
#
# <b>Teacher Note:</b>
#
# - You can walk students through 3.1 - 3.3 and have students try 3.5 - 3.7 on their own.
# - The goal here is to contrast positive and negative relationships.
#
# </div>

# %% [markdown]
# <div class="guided-notes">
#
# ### 3.1 Write code to create a scatter plot to explore our hypothesis: `total` = `speed` + other stuff
#
# A scatter plot can help us visualize the relationship between an explanatory variable and an outcome variable.
#
# The general format for creating a scatter plot in R is: `gf_point(outcome ~ explanatory, data = dataframe)`
#
# </div>

# %% [markdown]
# *type your response here*

# %% [markdown]
# <div class="teacher-note">
#
# <b>Teacher Note:</b>
# Encourage students to also write their word equation using **function notation**:
# - For example: <code>total = f(speed)</code>
# This reinforces the idea that we're modeling a rule or relationship — even if we don’t know the full equation. It also connects to later ideas about functions and predictions.
#
# </div>

# %%
# edit this
gf_point(outcome ~ explanatory, data = dataframe)

# %%
# COMPLETE
gf_point(total ~ speed, data = Pokemon)

# %% [markdown]
# <img src="https://i.postimg.cc/fL37ygGP/330.png" title="venusaur" width = 25% style = "float: right">
#
# ### 3.2 Let's try to predict where Flygon, who has a `speed` value of 100, would be on the scatter plot.
# Use the code cell below to plot a point to represent where you think Flygon would be.

# %%
gf_point(total ~ speed, data = Pokemon) %>% # the %>% is a "pipe" and you use it add something to your graph
    gf_point(Y ~ X, color = "darkorange")

# %%
#COMPLETE 
gf_point(total ~ speed, data = Pokemon) %>% 
    gf_point(250 ~ 100, color = "maroon2", shape = 17, size = 4) %>% # too low
    gf_point(750 ~ 100, color = "royalblue1", shape = 15, size = 3)%>% # too high 
    gf_point(520 ~ 100, color = "darkorange", shape = 8, size = 4) # actual

# %% [markdown]
# <div class="teacher-note">
#
# **Teacher Note:**
#
# You can collect different predictions from students and plot them on the scatterplot to compare. This is a great opportunity to talk about what makes a prediction "reasonable."
#
# Alternatively (or in addition), you can purposefully highlight some predictions that are clearly *too low* or *too high*. For example, one point might be far below most other Pokémon with similar `speed`, and another might be far above.
#
# Ask students: *How can we tell those predictions are off?*
# Encourage them to notice that the best prediction usually falls somewhere **in the middle** of the data cloud for that speed value. This connects to the idea of using patterns in the data (not just guesses) to make informed predictions.
#
# </div>

# %% [markdown]
# ### Explain what your prediction means and how you chose it.
#
# - What `speed` value did you use?
# - What `total` score did you predict for that Pokémon?
# - How did you decide on that number? What did you notice in the graph?

# %% [markdown]
# *type your response here*

# %% [markdown]
# <div class="teacher-note">
#
# <b>Teacher Note:</b> This is a great moment to introduce or reinforce **function notation**. Ask:
# - “If we think of `total = f(speed)`, how could we write your prediction as a function statement?”
# - Example: <code>f(100) = 550</code> means you're predicting a total score of 550 for a Pokémon with speed 100.
#
# This helps connect informal reasoning to formal function language — even if students aren’t using equations yet.
#
# </div>

# %% [markdown]
# <div class="discussion-question">
#
# ### 3.3 Key Discussion Question: Do you think the variable `speed` helps explain some of the differences we see in `total`?
# - If yes, what do you see in the graph that makes you think that?
# - If no, why not?
#
# </div>

# %% [markdown]
# *type your response here*

# %% [markdown]
# <div class="teacher-note">
#
# <b>Teacher Note:</b>
# As students discuss the relationship between speed and total, this is a great chance to surface early ideas about:
# - What kinds of values speed takes on (inputs) and what kinds of total values come out (outputs).
# - Whether those values are tightly grouped or show a lot of variation.
# - Whether there’s a general trend — do higher speeds tend to go with higher total scores?
#
# You might say:
# - “If you had to describe the overall shape of the graph, what direction does it seem to be moving?”
# - This helps students reason about domain and range, variation, and direction of the relationship — all key building blocks for later function modeling.
#
# </div>

# %% [markdown]
# ### 3.4 Comparing Two Predictors
# Now let’s compare how well two variables help explain total:
# Edit the code below to look at the graphs of `total` vs. `speed` and `total` vs. `attack`.

# %%
# run this code to make the total vs. speed scatter plot 
gf_point(total ~ speed, data = Pokemon)

# write code to make the total vs. attack scatter plot

# %%
# COMPLETE
# run this code to make the total vs. speed scatter plot 
gf_point(total ~ speed, data = Pokemon)

# write code to make the total vs. attack scatter plot 
gf_point(total ~ attack, data = Pokemon)

# %% [markdown]
# <div class="teacher-note">
#
# **Teacher Note:**
#
#  <li>Remind students that the variable they’re using to try to “explain” or “predict” total strength goes on the x-axis. A common mistake is reversing the order of variables, which produces a valid plot but misrepresents the question. Have students reread their scatterplot title or labels to double check.
#  <li> This is a good place to use a <i>driver / navigator</i> pedagogy: You be the driver, but call on one or more students "navigate" (i.e., tell you what to type into the code window. tuition about **good predictors** — not necessarily ones that are perfect, but ones that show a visible pattern.
#
# </div>

# %% [markdown]
# ### Which variable looks like a better predictor of `total`?
# - Which graph shows a clearer trend or pattern? Why?
# - Does one graph have more "scatter" or randomness than the other?

# %% [markdown]
# *type your response here*

# %% [markdown]
# <div class="teacher-note">
#
# **Teacher Note:**
# The two scatterplots (Total vs. Speed and Total vs. Attack) are stacked vertically here to allow for meaningful comparison.
#
# - Encourage students to compare the shape and strength of the patterns. Which graph shows a clearer relationship between the explanatory variable and total?
# - Some students may notice that Attack has a more consistent upward trend, while Speed shows more variability.
# - Use this moment to build intuition about **good predictors** — not necessarily ones that are perfect, but ones that show a visible pattern.
#
# </div>

# %% [markdown]
# <div class="guided-notes">
#
# ### 3.5 Write code to create a scatter plot to explore our hypothesis: `total` = `capture_rate` + other stuff
#
# A scatter plot can help us visualize the relationship between an explanatory variable and an outcome variable.
#
# The general format for creating a scatter plot in R is: `gf_point(outcome ~ explanatory, data = dataframe)`
#
# </div>

# %% [markdown]
# <div class="teacher-note">
#
# <b>Teacher Note:</b> Connect back to function notation
# </div>

# %%
# edit this
gf_point(outcome ~ explanatory, data = dataframe)

# we used the color "darkorange" before, but you can try another color like "red"

# %%
# COMPLETE
gf_point(total ~ capture_rate, data = Pokemon, color = ~(name =="Swirlix"))

# %% [markdown]
# <img src="https://i.postimg.cc/KYmL6VtC/800px-0684-Swirlix.png" width = 25% style = "float: right">
#
# ### 3.6 Let's try to predict where Swirlix, who has a `capture_rate` value of 200, would be on the scatter plot.
# Add a point to the the code cell above to plot a point to represent where you think Swirlix would be.

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# Totally extra, but if you'd like to see more colors available in R, checkout [this color cheatsheet](https://bookdown.org/hneth/ds4psy/D.3-apx-colors-basics.html)!
# </div>

# %% [markdown]
# ### Explain what your prediction means and how you chose it.
#
# - What `capture_rate` value did you use?
# - What `total` score did you predict for that Pokémon?
# - How did you decide on that number? What did you notice in the graph?

# %% [markdown]
# *type your response here*

# %% [markdown]
# <div class="teacher-note">
#
# <b>Teacher Note:</b>  Encourage students to interpret their prediction in words and optionally write it using **function notation**. Ask:
# - “If we're thinking of `total = f(capture_rate)`, what would your prediction look like as a function?”
# - For example: <code>f(45) = 680</code> means a Pokémon with capture rate 45 is predicted to have a total score of 680.
#
# This helps students connect their reasoning to the structure of a function — even if they haven’t written a rule.
#
# </div>

# %% [markdown]
# <div class="discussion-question">
#
# ### 3.7 Key Discussion Question: Do you think the variable `capture_rate` helps explain some of the differences we see in `total`?
# - If yes, what do you see in the graph that makes you think that?
# - How does this relationship compare to what you saw with `speed`?
# - What might a low capture rate tell us about a Pokémon’s strength?
# </div>

# %% [markdown]
# *type your response here*

# %% [markdown]
# <div class="teacher-note">
#
# **Teacher Note:** Students should notice a negative relationship between capture_rate and total: Pokémon that are harder to catch (low capture rate) tend to be stronger (higher total). This contrasts with speed, which had a positive relationship.
#
# Prompt students to interpret what this means:
# - Why might powerful Pokémon be harder to catch?
# - Do we always see this pattern, or are there exceptions?
#
# You can also build early intuition for domain and range by asking:
# - What kinds of capture_rate values show up?
# - How much do total values vary for a given capture rate?
#
# If you highlighted Swirlix, use it to show how data trends can help us make reasonable guesses, even if they're not perfect.
#
# </div>

# %% [markdown]
# ## 4.0 What does a *less good* predictor look like?
# So far, we’ve looked at variables like `speed`, `attack`, and `capture_rate` — all of which show a pretty clear relationship with `total`. But not all variables are good predictors...

# %% [markdown]
# <div class="guided-notes">
#
# ### 4.1 Run the code below to create a scatter plot to explore our hypothesis: `total` = `weight` + other stuff
#
# A scatter plot can help us visualize the relationship between an explanatory variable and an outcome variable.
#
# The general format for creating a scatter plot in R is: `gf_point(outcome ~ explanatory, data = dataframe)`
#
# </div>

# %% [markdown]
# <div class="teacher-note">
#
# <b>Teacher Note:</b> Connect back to function notation
# </div>

# %%
gf_point(total ~ weight, data = filter(Pokemon, weight < 125))

# We filtered to only include Pokémon with weight < 125 to make the relationship easier to see.

# %% [markdown]
# <div class="teacher-note">
#
# <b>Teacher Note:</b> Because `weight` is skewed right (About 75% weigh under 64.8 kg), we added a domain restriction by using the filter() command
# </div>

# %% [markdown]
# <div class="discussion-question">
#
# ### 4.2 Key Discussion Question: do you think this explanatory variable (`weight`) can help us predict a Pokémon's `total` strength?
# If yes, where in the graph do you see evidence of this? If no, why not?
#
# </div>

# %% [markdown]
# *type your response here*

# %% [markdown]
# <div class="teacher-note">
#
# <b>Teacher Note:</b>
#
# There is a slight positive relationship, but it's very weak. We would say there is not really a correlation or relationship between a Pokémon's `total` and their `weight`. That is, `weight` doesn't really help us predict how strong a Pokémon is.
#
# What we are doing here is trying to **explain variation**: If we know a case’s value on one variable, we can make a better prediction of its value on another variable -- but that's a lot harder with weight than speed or attack.
#
# <b>Optional Extension Note:</b> You could also connect this to domain/range thinking by asking:
# - Are there weights where we see a wide range of totals?
# - What does that tell us about how useful `weight` is for making predictions?
# This reinforces the idea that a *function* has a predictable output — and `weight` doesn’t behave that way here.
#
# </div>

# %% [markdown]
# <div class="teacher-note">
#
# <b>Optional Extenstion:</b> If you'd like to help students see an example of a relationship that doesn't behave like a function, consider showing the full weight vs total scatterplot (without filtering).
# - There’s a thick vertical cluster of points, especially at lower weights — almost like a vertical line. That means many Pokémon with the same or similar weights have very different total scores.
# - This can be a great opportunity to:
#     - Reinforce that a function has one output for each input — and this clearly doesn’t!
#     - Highlight why weight is a poor predictor of total, since it doesn’t explain the variation well.
#
# </div>

# %%
# optional extension 
gf_point(total ~ weight, data = Pokemon)

# %% [markdown]
# ## 5.0 Adding More Explanatory Variables to a Graph
# Now that we’ve seen how to visualize the relationship between one explanatory variable and an outcome, let’s try adding more explanatory variables.

# %% [markdown]
# <div class="discussion-question">
#
# ### 5.1 Key Discussion Question: How would you write a word equation to express the hypothesis that **both** speed and whether or not a Pokémon uses `magic` explain variation in a its strength?
#
# </div>

# %% [markdown]
# *write your word equation here*

# %% [markdown]
# <div class="teacher-note">
#
# <b>Teacher Note:</b>
# This question is a chance for students to combine both a quantitative variable (`speed`) and a categorical one (`magic`) in their model. Encourage them to write a clear word equation — and then connect it to function notation.
#
# Example:
# - Word equation: <code>total = speed + magic + other stuff</code>
# - Function notation: <code>total = f(speed, magic) + other stuff</code>
#
# You might prompt students:
# > “What do you think `magic` is doing in this model? Is it increasing or decreasing strength?”
#
# The goal is not to get a perfect rule, but to practice expressing multivariable thinking — a big step toward more flexible models.
#
# </div>

# %% [markdown]
# ### 5.2 Using color to represent an additional explanatory variable
#
# We've created a scatter plot below to show `total` as a function of `weight`. Try adding in the argument `color = ~magic` and see what happens.
#
# (Try using `shape` or `size` instead of `color` to see what happens.)

# %% [markdown]
# <div class="teacher-note">
#
#  <b>Teacher note:</b>
#  <ul>
#  <li>Most variables won't show a pattern. Legendary shows the clearest difference (but you might want to save that discover for students to make on their own).
#  <li>You can also model coloring by a quantitative variable, which will use shading --> opportunity to review/define categorical and quantitative variables
#  <li> Students might expect type to be a good predictor, but there are so many types, it's really hard to see any pattern. Suggest category instead. Alternatively, you can show them how to color one type or value: gf_point(total ~ weight, data = Pokemon, color =  ~(type1 == "electric"))
# </div>

# %%
# edit this code 
gf_point(total ~ speed, data = Pokemon)

# %%
# COMPLETE
gf_point(total ~ weight, data = Pokemon, color =  ~magic)

#the default colors should be fine for colorblind students, but you can use shape too
gf_point(total ~ weight, data = Pokemon, color =  ~magic, shape = ~magic)

# %% [markdown]
# ### 5.3 Your turn! Explore another hypothesis.
#
# Write a word equation that hypothesizes **two explanatory variables** to explain variation in a Pokémon's `total`. Then edit the code to visualize your hypothesis.

# %% [markdown]
# *write your word equation here*

# %%
# write some code here

# %%
glimpse(Pokemon)

# %%
# COMPLETE

#sample response 
gf_point(total ~ attack, data = Pokemon, color = ~legendary)
gf_point(total ~ capture_rate, data = Pokemon, color = ~friendship)
gf_point(total ~ defense, data = Pokemon, color = ~attack)
gf_point(total ~ speed, data = Pokemon, color = ~(type1 =="dragon"))

# %% [markdown]
# *What does your scatter plot tell you about Pokémon? Jot some observations here.*

# %% [markdown]
# <div class="teacher-note">
#
# <b>Sample responses:</b>
#
# <ul>
#   <li>"There’s a positive trend—higher attack values are linked with higher total scores."</li>
#   <li>"It looks like there’s a lot of spread, especially for lower values of speed."</li>
#   <li>"Some Pokémon have high capture rates but low total, so it seems like being easier to catch doesn't mean they’re stronger."</li>
# </ul>
#
# <b>Teacher Note:</b> Encourage precise language: trends (increasing/decreasing), clustering, outliers, and variation. Ask: “Would you expect this relationship to continue for even stronger/faster Pokémon?” You might also ask them to compare steepness or direction of different plots across the class.
#
# </div>

# %% [markdown]
# ### Final Reflection: What Did You Learn?
#
# Pick one of the questions below to answer:
#
# - What did you learn about Pokémon in today’s activity?
# - If you were choosing a Pokémon for battle, what would you look for and why?
# - If you wanted to create an unbeatable Pokémon, what characteristics would it have and why?
# - What surprised you about the data or your graph?

# %% [markdown]
# <div class="teacher-note">
#
# <b>Sample responses:</b>
#
# <ul>
#   <li>"I learned that Pokémon with higher Attack usually have higher HP too."</li>
#   <li>"I’d choose a Pokémon with strong Attack and Defense—it seems like those are good predictors of Total Strength."</li>
#   <li>"I was surprised that Speed didn’t matter as much as I expected."</li>
# </ul>
#
# <b>Teacher Note:</b> This closing reflection helps reinforce both data exploration and functional thinking. Use it to connect mathematical reasoning to real-world decision making and give students a chance to synthesize what they’ve discovered.
#
# </div>
