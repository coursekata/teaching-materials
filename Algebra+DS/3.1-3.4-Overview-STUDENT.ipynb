# %% [markdown]
# # Which colleges are worth the price of admission? <img src="https://i.postimg.cc/sX3pctKT/360-F-362439371-lf-Y3-Sr-Bbk-Cs-MX2scf2yd8-PS0-Uczajfd-L.jpg" width="200" style="display:inline; margin-left:10px;">
# ## Chapter 1.8-1.9 Overview Notebook
#
# ## Does college *really* pay off?
#
# In this notebook, you’ll explore real data from the U.S. Department of Education’s [College Scorecard](https://collegescorecard.ed.gov/data/) to investigate this question.
#
# As the cost of college keeps rising, students and families are asking:
# - *Is it worth the price?*
# - *Which schools give the best return on investment?*
# - *Can we predict which colleges are riskier when it comes to student debt and default?*

# %% [markdown]
# ## 0.0: Launch — Why Is College So Expensive?
#
# Before we start looking at any data, let’s build some background. College in the U.S. has gotten dramatically more expensive over the last few decades — but *why*?
#
# We will watch a short video to understand how the cost burden has shifted — and how students are affected today.

# %% [markdown]
# ### 0.1 Individual reflection
#
# After watching the video, take some time to think about and respond to these questions:
#
# - What’s one reason college costs have gone up?
# -  Who do you think is most affected by rising college costs?
# - What questions do you have about college, cost, or debt?

# %% [markdown]
# *jot some ideas here*

# %% [markdown]
# ### 0.2 Pair/group disucssion
#
# Now, with a partner or group, discuss your answers. Then agree on one question you’d like to investigate with data.

# %% [markdown]
# *Write down your shared question here*

# %% [markdown]
# ## 0.3 Run the code cell below to set up the notebook and load the data.

# %%
# run this code to load coursekata's library of R functions
suppressPackageStartupMessages({
    library(coursekata)
})

# set styles
css <- suppressWarnings(readLines("https://raw.githubusercontent.com/jimstigler/jupyter/master/ck_jupyter_styles_v2.css"))
IRdisplay::display_html(sprintf('<style>%s</style>', paste(css, collapse = "\n")))

hawaii <- read.csv('https://skewthescript.org/s/colleges.csv') %>%
  filter(state == "HI") %>%
  select(name, default_rate, avg_cost) %>%
  arrange (avg_cost)
 
# This command grabs data from a csv file stored in google docs
# and puts it in a data frame called colleges
colleges <- read.csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vRSCbBDGKuckuHwWg0H6tlXat6gvWzKTyqnkUAw_oyXTBVhDgK5aSzWggLXXEjaFp-tT7SsBIXxHCxi/pub?output=csv')

print("🏫")

# %% [markdown]
# ## 1.0: Get to Know the Dataset (`colleges`)
#
# The dataset you’ll be working with comes from the [**College Scorecard**](http://collegescorecard.ed.gov/data), a database from the U.S. Department of Education.
#
# It includes information about:
# - Who goes to different colleges
# - How much those colleges cost
# - How students are doing after college — including **loan default rates**

# %% [markdown]
# ### 1.1 Look at the variables
#
# Take a look at your <a href="https://docs.google.com/document/d/e/2PACX-1vTx1RIMuiDrjhXD-EYb__ePhoc8satho_6HlNbnFnM6ubQvude3p88MXsJTYI12LnApZ8F-Zu_3ALvu/pub">handout</a> which lists all the variables and a brief description for `colleges`.

# %% [markdown]
# ### What do you notice? What do you wonder?
#
# - Are there any variables you recognize or are curious about?
# - Which ones might connect to what we saw in the video?
# - Which ones might help us figure out which colleges are “worth it”?

# %% [markdown]
# *jot some ideas here*

# %% [markdown]
# ### 1.2 Write some code to look at the `colleges` data frame.

# %%
# write some code to look at the data frame

# %% [markdown]
# ### 1.2 Our goal today is to think about *which colleges are worth the price of admission?*
#
# Why might we look at default_rate when deciding whether college is a good investment?
#
# >`default_rate` is the percent of school's borrowers in default on student loans (from recent cohorts). Includes students who graduate, transfer, or dropout.

# %% [markdown]
# *type your response here*

# %% [markdown]
# ### 1.3 What does a low default rate mean? What does a high default rate mean?

# %% [markdown]
# *type your response here*

# %% [markdown]
# ### 1.4 Pick a few variables that you think might help us *predict* a college's `default rate`.
# Why did you pick them?

# %% [markdown]
# *type your response here*

# %% [markdown]
# ## 2.0: Explore a hypothesis

# %% [markdown]
# ### 2.1 What is your hypothesis about college default rates?

# %% [markdown]
# *I think ... because ...*

# %% [markdown]
# ### 2.2 What variable(s) do you think might help explain or predict default rate?

# %% [markdown]
# *write a word equation here*

# %% [markdown]
# ### 2.3 Use R to graph your hypothesis
# Make a scatterplot of `default_rate` against one variable from your word equation.

# %%
gf_point(Y ~ X, data = colleges)

# %% [markdown]
# ### What does your graph tell you about `default_rate`?

# %% [markdown]
# *type your response here*

# %% [markdown]
# ### 2.4 Add a Line to Model Your Data
#
# Let’s try adding a line to your scatterplot to model the relationship you see. Then reflect on your linear model:
#
# - What does your line say about the relationship between the two variables?
# - How well do you think your line fits the data?
# - What might be good or bad about using a line to model this pattern?

# %% [markdown]
# *type your response here*

# %% [markdown]
# ### 2.5 Compare Hypotheses
#
# Let’s take a step back and look at what you and your classmates are discovering. With a partner or group:
#
# 1. Take turns showing your **scatterplots** from 2.3.
# 2. Explain the **hypothesis** and **word equation** you wrote.
# 3. Try to answer these questions together:
#
# - What is similar or different about your graphs?
# - Which variables seem to show the clearest or strongest relationship with `default_rate`?
#     - What evidence do you have (from scatterplots, slope, or line fit)?
# - Are there any patterns that were surprising or different than you expected?
# - If you had to choose one variable to model default_rate, which would it be? Why?

# %% [markdown]
# *type your response here*

# %% [markdown]
# ## 3.0: A Closer Look: Hawai‘i Colleges

# %% [markdown]
# We’re going to focus on a small set of schools — just those in Hawai‘i — and test a model together. Instead of everyone creating their own hypothesis, let’s evaluate one possible model as a group.
#
# ### 3.1 Take a look at another dataset called `hawaii`.

# %%
# print the whole data set 
hawaii

# %% [markdown]
# ### 3.2 Create a scatterplot for the following word equation:
#
# <div class="alert alert-block alert-warning">
#
# #### default_rate = avg_cost + Other Stuff
#
# </div>

# %%
# write some code here

# %% [markdown]
# <img src="https://i.postimg.cc/1tPc2cjS/CK-Icons-2.png"/>

# %% [markdown]
# <div class="guided-notes">
#
# ## 4.0 Comparing Models
# Each group will get a graph with a function model for the `hawaii` dataset, and some are better than others. Let's explore how to **evaluate** these models.

# %% [markdown]
# <div class="guided-notes">
#
# ### 4.1 Write Your Model
#
# At the top of your table, write the equation of the line your group was given.

# %% [markdown]
# <div class="guided-notes">
#
# ### 4.2 How far off is your model?
# Complete the table in your guided notes. For each college...
# - Predict the `default_rate`: plug in the`avg_cost` into your model and record the result in your table
# - How far off are the predictions? Calcuate the **error** for each prediction and record them in your table.
# - Show the error on your group's graph.

# %% [markdown]
# <div class="guided-notes">
#
# ### 4.3 What is the total error?
# Find the **total error** to show how far off the model is overall.

# %% [markdown]
# <div class="guided-notes">
#
# ### 4.4 Quantifying and representing error.
# Take a moment to summarize what you just practiced with your group. Add these ideas to your notes as we go over them together:
#
# - What does *error* (or *residual*) mean?
# - How do we calculate it?
# - What’s the difference between a **positive** and a **negative** residual?
# - How can we show residuals on a graph?

# %% [markdown]
# <div class="guided-notes">
#
# ### 4.5  Which model has the least error?
#
# Now that each group has calculated their total error, it’s time to compare.
#
# Walk around the room and look at the graphs + tables from other groups.
# As you go, pay attention to:
# - Which model(s) had the **smallest total error**?
# - Which models had a lot more error?
# - Did any models *look good* but actually had a high total error?
# - Did any models *look bad* but actually had a low total error?

# %% [markdown]
# <div class="guided-notes">
#
# ### 4.6 Are the models with the lowest total error always the best?
#
# Think about what you noticed during the gallery walk.
#
# - Do you think the model(s) with the lowest total error are always the best models?
# - Why or why not?
